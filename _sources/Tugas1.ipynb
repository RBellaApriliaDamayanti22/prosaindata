# %% [markdown]
# # CRAWLING TWITTER

# %% [markdown]
# ## 1. Install snscrape

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.8/dist-packages (0.5.0.20230113)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %%
from tqdm.notebook import tqdm
from ipywidgets import FloatProgress
import csv
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
scraper=sntwitter.TwitterSearchScraper("sandiuno")
tweets=[]
n_tweets=500
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data=[
        tweet.user.username, 
        tweet.rawContent, 
        tweet.user.location,
    ]
    tweets.append(data)
    if i > n_tweets:
        break
tweet_df=pd.DataFrame(tweets, columns=['@Username','Tweet', 'Lokasi'])
tweet_df
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#           @Username                                              Tweet  \
# 0       MafazartAdv  @NastarBubuk @roses_man @parlinburman84 @hadad...
# 1       NastarBubuk  @MafazartAdv @roses_man @parlinburman84 @hadad...
# 2     imam_rachman_  Menparekraf Upayakan Harga Tiket Pesawat Murah...
# 3         KentKukuh  @tempodotco Eitttt.. Sandiuno jgn dipasangkan ...
# 4      koffie_lover  @en_jeu_L @sandiuno @aniesbaswedan @Fahrihamza...
# ..              ...                                                ...
# 497        sandiuno  Kami akan terus memperjuangkan ekonomi masyara...
# 498     bladestromm  @wandadesign755 @sandiuno @BaleBengong Governm...
# 499  wandadesign755  @bladestromm @sandiuno @BaleBengong Wonder why...
# 500     bengkeldodo  @KhoirilAnwar_ @prabowo @hattarajasa @sandiuno...
# 501     bladestromm  Garbage not picked up for days in kuta beach t...
#
#                                 Lokasi
# 0                 Cileungsi, Indonesia
# 1                            Indonesia
# 2
# 3               Pangkalan bun kal_teng
# 4    Jakarta Capital Region, Indonesia
# ..                                 ...
# 497
# 498                     Denpasar, Bali
# 499                               Bali
# 500                 Kebumen, Indonesia
# 501                     Denpasar, Bali
#
# [502 rows x 3 columns]

# %%
tweet_df.to_csv('Twitter-.csv', index=False)

# %% [markdown]
# # Crawling data Website https://pta.trunojoyo.ac.id/

# %% [markdown]
# ## 1. Install modul Beautifulsoup dan request and Import library

# %%
import requests 
from bs4 import BeautifulSoup 
import csv
import pandas as pd
#agent user : supaya web server menampilkan konten yang dimiliki sesuai dengan OS yang kita gunakan, jadi web server tau browser dan OS yang kita gunakan
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}

# %% [markdown]
# ## Peroses crawling menggunakan bs4 dan request

# %%
#Inisialisasi Link URL
url = 'https://pta.trunojoyo.ac.id/c_search/byprod/10/'

headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
    }

#Inisialisai list untuk menginputkan hasil crawling kedalam sebuah list
listJudul = []
listPenulis = []
listAbstrak = []

#proses perulangan untuk crawling data
for page in range(1,172):
  req = requests.get(url+str(page), headers=headers)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('li',{'data-id':'id-1'})
  for it in items:
    try: link = it.find('a', 'gray button')['href']
    except : link=''
    try: title = it.find('a', 'title').text 
    except : title=''
    try: penulis = it.find('span').text.replace('Penulis :','') 
    except : penulis=''

    if it != '':
      listJudul.append(title)
      listPenulis.append(penulis)
      req2 = requests.get(str(link), headers=headers)
      soup2 = BeautifulSoup(req2.text, 'html.parser')
      items2 = soup2.findAll('li',{'data-id':'id-1'})
      for it2 in items2:
        try : abstrak = it2.find('p',{'align':'justify'}).text
        except : abstrak=''

        if it2 != '':
          listAbstrak.append(abstrak)
  
judul = pd.DataFrame(listJudul,columns=["Judul"])
penulis = pd.DataFrame(listPenulis,columns=["Penulis"])
abstrak = pd.DataFrame(listAbstrak,columns=["Abstrak"])
data = pd.concat([penulis,judul, abstrak], axis=1) 
data
# Out:
#                     Penulis  \
# 0        A.Ubaidillah S.Kom
# 1       M. Basith Ardianto,
# 2     Akhmad Suyandi, S.Kom
# 3           Heri Supriyanto
# 4      Septian Rahman Hakim
# ..                      ...
# 850     Devi Editya Susanti
# 851                Kumayyah
# 852       Ahmad Faris Ihsan
# 853   Rachmad Agung Pambudi
# 854        Nadila Hidayanti
#
#                                                  Judul  \
# 0    PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE \...
# 1    APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 2    RANCANG BANGUN APLIKASI PROXY SERVER UNTUK\r\n...
# 3    SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 4    SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
# ..                                                 ...
# 850  Sistem Peramalan Stok Barang dengan menggunaka...
# 851  Sistem Rekomendasi Dalam Menentukan Posisi Dep...
# 852  MULTI CRITERIA DECISION MAKING UNTUK MENENTUKA...
# 853  PENERAPAN ALGORITMA LONG-SHORT TERM MEMORY UNT...
# 854  SISTEM PENCARIAN TEKS AL-QURAN TERJEMAHAN BERB...
#
#                                                Abstrak
# 0    Sistem  informasi  akademik  (SIAKAD) merupaka...
# 1    Berjalannya koneksi jaringan komputer dengan l...
# 2    Web server adalah sebuah perangkat lunak serve...
# 3    Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 4    Seiring perkembangan teknologi yang ada diduni...
# ..                                                 ...
# 850  Toko tas Deeolshop menjual berbagai macam tas ...
# 851  Sepak bola adalah salah satu olahraga yang saa...
# 852  Perguruan Tinggi merupakan salah satu jenjang ...
# 853  Investasi saham selama ini memiliki resiko ker...
# 854  Information Retrieval (IR) merupakan pengambil...
#
# [855 rows x 3 columns]

# %%
TA=scrape_TA(10)
TA_result = pd.DataFrame(TA)
TA_result.columns = ["NPM", "Judul","Abstrak","Prodi"]
TA_result
# Out:
#             NPM                                              Judul  \
# 0  040411100468  PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE T...
# 1  040411100476  APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 2  040411100480  RANCANG BANGUN APLIKASI PROXY SERVER UNTUKENKR...
# 3  070411100070  SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 4  080411100115  SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
# 5  070411100007  Gerak Pekerja Pada Game Real Time Strategy Men...
# 6  070411100126  RANCANG BANGUN GAME PERAWATAN SAPI KARAPAN MEN...
# 7  070411100109  EKSTRAKSI FITUR BERBASIS TWO DIMENSIONAL LINEA...
# 8  080411100083  IMPLEMENTASI  ALGORITMA PRIM  DAN DEPTH FIRST ...
# 9  070411100092  Perancangan Sistem Informasi Badan Kepegawaian...
#
#                                              Abstrak               Prodi
# 0  Sistem  informasi  akademik  (SIAKAD) merupaka...  Teknik Informatika
# 1  Berjalannya koneksi jaringan komputer dengan l...  Teknik Informatika
# 2  Web server adalah sebuah perangkat lunak serve...  Teknik Informatika
# 3  Penjadwalan  kuliah  di  Perguruan  Tinggi  me...  Teknik Informatika
# 4  Seiring perkembangan teknologi yang ada diduni...  Teknik Informatika
# 5  Gerak pekerja ada pada game yang memiliki genr...  Teknik Informatika
# 6  Perkembangan game yang semakin pesat, memberik...  Teknik Informatika
# 7  Sistem pengenalan wajah adalah suatu sistem un...  Teknik Informatika
# 8  Teknologi mobile game beroperating system open...  Teknik Informatika
# 9  Kantor Badan Kepegawaian kota Bangkalan adalah...  Teknik Informatika

# %% [markdown]
# ## Export To CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/prosaindata/CrawlingWebPTA.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  TA_result.to_csv(f)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Crawling data Website Berita CNN
#
# ---

# %% [markdown]
# ## 1. Install modul Beautifulsoup dan requests

# %%
# !pip install requests
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %% [markdown]
# ## 2. Import library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## 3. Peroses crawling menggunakan bs4 dan request

# %%
#Inisialisasi Link URL
url = 'https://www.cnnindonesia.com/indeks'

headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
    }

#inisialisasi list untuk memasukkan hasil crawling kedalam list
listJudul = []
listIsi = []

#proses perulangan untuk crawling data
for page in range(1,4):
  req = requests.get(url+str(page), headers=headers)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('article')
  for it in items:
    try: link = it.find('a')['href']
    except : link=''
    try: title = it.find('h2', 'title').text 
    except : title=''
    
    if title != '':
      listJudul.append(title)

    if link != '':
      req2 = requests.get(str(link), headers=headers)
      soup2 = BeautifulSoup(req2.text, 'html.parser')
      items2 = soup2.findAll("div", "detail_text")
      for it2 in items2:
        try : berita = it2.find('p').text
        except : berita=''

        if berita != '':
          listIsi.append(berita)


df_Judul = pd.DataFrame(listJudul, columns=["Judul Berita"])
df_Isi = pd.DataFrame(listIsi, columns=["Isi Berita"])

data = pd.concat([df_Judul, df_Isi], axis=1)
data = data.loc[0:50]
data
# Out:
#                                          Judul Berita  \
# 0   Edy Soal Pilgub Sumut: Kalau yang Maju Abal-ab...
# 1   PKB Bakal Daftarkan Menaker Ida Fauziyah Jadi ...
# 2   Bahan Peledak di Blitar Tergolong Low Explosiv...
# 3   Dokumen Kremlin Diklaim Bocor Sebut Rencana Ru...
# 4   Putin: Barat Sudah Rusak, Desak Pendeta Berkat...
# 5   Putin Klaim AS-NATO Sudah Merencanakan Perang ...
# 6   Pengamat Sebut Pangsa Pasar Kendaraan Listrik ...
# 7   Sri Mulyani Wanti-wanti Soal Lonjakan Harga Pa...
